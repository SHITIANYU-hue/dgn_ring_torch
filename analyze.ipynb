# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
score=np.load('scores.npy')

# %%
len(score)
# Out:
# 100

# %%
plt.plot(score[0:100])

# %%
loss=np.load('loss.npy')

# %%
plt.plot(loss)
