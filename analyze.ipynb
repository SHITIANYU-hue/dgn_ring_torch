# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
score=np.load('scores.npy')
plt.plot(score)

# %%
loss=np.load('loss.npy')
plt.plot(loss)

# %%
car_total_distance = np.load('car_total_distance.npy')
plt.plot(car_total_distance)

# %%
num_crash = np.load('car_crashs.npy')
plt.plot(num_crash)

# %%
outflow = np.load('ES_Total_scores.npy')
plt.plot(outflow)

# %%
speed_limit = np.load("ES_spped_limit.npy")
speed_limit.shape
# Out:
# (130, 10)

# %%
for i in range(speed_limit.shape[1]):
    plt.plot(speed_limit[:, i], label='rl_0_{}'.format(i))
plt.legend()

# %%
average_speed = np.load("average_speed.npy")
plt.plot(average_speed)

# %%
punish_accel = np.load("punish_accel.npy")
plt.plot(punish_accel)

# %%
headway_limit = np.load('headway_limit.npy')
plt.plot(headway_limit)
